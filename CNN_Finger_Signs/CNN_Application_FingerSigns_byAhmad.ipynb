# %% [markdown]
# ## "Convolutional Neural Network Application"<br>
# <img src="./images/multi_class.jpg" style="">
# <caption><center><b> <font color="blue">Fig1. FingerSign dataset</font></b></center></caption>

# %% [markdown]
# ## Functional API

# %%
# importing fundamental packages:
# import:
import math
import h5py
import scipy
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras.layers as tfl

# form:
from PIL import Image
from cnn_utils import *
from matplotlib.pyplot import imread
from test_utils import summary, comparator
from tensorflow.python.framework import ops
from tensorflow.keras.utils import to_categorical

# magic command:
np.random.seed(1)
# %matplotlib inline

# %% [markdown]
# ### 1) loading the Data and split data into Train/Test sets:
#
# - dataset => <b>Finger Signs dataset</b> => containing images of human's finger sign.
# - type => <b>multi-Class classification</b> => finger signs, 0, 1, 2, 3, ..., 6

# %%
# loading the dataset => data sign:
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_signs_dataset()

# %%
# preprocessing part:

# normalizing images:
X_train = X_train_orig / 255
X_test = X_test_orig / 255

Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_test = convert_to_one_hot(Y_test_orig, 6).T

# printing:
print(f"number of training example: {X_train.shape[0]}")
print(f"number of test example: {X_test.shape[0]}")
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"Y_train shape: {Y_train.shape}")
print(f"Y_test shape: {Y_test.shape}")
# Out:
# number of training example: 1080
# number of test example: 120
# X_train shape: (1080, 64, 64, 3)
# X_test shape: (120, 64, 64, 3)
# Y_train shape: (1080, 6)
# Y_test shape: (120, 6)

# %%
# visualizing our dataset:
# one image:
image_index = 9
plt.imshow(X_train_orig[image_index])
print ("y = " + str(np.squeeze(Y_train_orig[:, image_index])))
plt.show()
# Out:
# y = 4

# %% [markdown]
# ### Keras API Functional mode:
# - in the Functional API, you can create a graph of layers.This is what allows such great flexibility.

# %%
# Creating convolutional model using Functional API:

def convolutional_model(input_shape):
    """
    Implemeting the forward propagation for the model:
    
    Conv2D => ReLU => MaxPool => Conv2D => ReLU => MaxPool => Flatten => Dense
    
    Arguments:
    input_image => input dataset, of shape (input_shape)
    
    Return:
    model => TF Keras model (object containig the informatoin for the entire training process.)
    
    """
    
    input_image = tf.keras.layers.Input(shape=input_shape)
    
    # Conv2D: 8 filters 4x4, stride of 1, padding 'same':
    Z1 = tf.keras.layers.Conv2D(filters=8,
                                kernel_size=(4,4),
                                strides=(1,1),
                                padding="same")(input_image)
    # Applying ReLU():
    A1 = tf.keras.layers.ReLU()(Z1)
    
    # MaxPool: window 8x8, stride 8, padding 'same':
    P1 = tf.keras.layers.MaxPool2D(pool_size=(8,8),
                                   strides=(8,8),
                                   padding="same")(A1)
    
    # CONV2D: 16 filters 2x2, stride 1, padding 'same':
    Z2 = tf.keras.layers.Conv2D(filters=16,
                                kernel_size=(2,2),
                                strides=(1,1),
                                padding="same")(P1)
    
    # Applying ReLU():
    A2 = tf.keras.layers.ReLU()(Z2)
    
    # MaxPool: window 4x4, stride 4, padding 'same':
    P2 = tf.keras.layers.MaxPool2D(pool_size=(4,4),
                                   strides=(4,4),
                                   padding="same")(A2)
    
    # Flatten layer:
    F = tf.keras.layers.Flatten()(P2)
    
    # Ouputs layer: (we have 6 classes => units=6 and activation = "softmax")
    outputs = tf.keras.layers.Dense(units=6, activation="softmax")(F)
    
    model = tf.keras.Model(inputs=input_image,
                           outputs=outputs)
    
    return model

# %%
# creating an object of the model:
conv_model = convolutional_model((64, 64, 3)) #input_shape =(64, 64, 3)

# compiling the model:
conv_model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# summary of the model:
conv_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 8)         392
# _________________________________________________________________
# re_lu (ReLU)                 (None, 64, 64, 8)         0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 16)          528
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 8, 8, 16)          0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 2, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 390
# =================================================================
# Total params: 1,310
# Trainable params: 1,310
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training the Model:
conv_model.fit(x=X_train,
               y=Y_train,
               validation_data=(X_test, Y_test),
               epochs=100,
               batch_size=64)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 6s 316ms/step - loss: 1.8391 - accuracy: 0.1769 - val_loss: 1.8005 - val_accuracy: 0.1750
# Epoch 2/100
# 17/17 [==============================] - 6s 373ms/step - loss: 1.7916 - accuracy: 0.2028 - val_loss: 1.7887 - val_accuracy: 0.1750
# Epoch 3/100
# 17/17 [==============================] - 5s 310ms/step - loss: 1.7832 - accuracy: 0.2194 - val_loss: 1.7847 - val_accuracy: 0.2167
# Epoch 4/100
# 17/17 [==============================] - 5s 310ms/step - loss: 1.7798 - accuracy: 0.2620 - val_loss: 1.7800 - val_accuracy: 0.2583
# Epoch 5/100
# 17/17 [==============================] - 6s 326ms/step - loss: 1.7753 - accuracy: 0.2750 - val_loss: 1.7767 - val_accuracy: 0.2583
# Epoch 6/100
# 17/17 [==============================] - 6s 328ms/step - loss: 1.7730 - accuracy: 0.2972 - val_loss: 1.7736 - val_accuracy: 0.2333
# Epoch 7/100
# 17/17 [==============================] - 5s 303ms/step - loss: 1.7680 - accuracy: 0.2769 - val_loss: 1.7688 - val_accuracy: 0.2750
# Epoch 8/100
# 17/17 [==============================] - 5s 324ms/step - loss: 1.7622 - accuracy: 0.3074 - val_loss: 1.7635 - val_accuracy: 0.3250
# Epoch 9/100
# 17/17 [==============================] - 6s 332ms/step - loss: 1.7584 - accuracy: 0.3157 - val_loss: 1.7582 - val_accuracy: 0.2667
# Epoch 10/100
# 17/17 [==============================] - 5s 292ms/step - loss: 1.7507 - accuracy: 0.3343 - val_loss: 1.7523 - val_accuracy: 0.2833
# Epoch 11/100
# 17/17 [==============================] - 5s 297ms/step - loss: 1.7427 - accuracy: 0.3509 - val_loss: 1.7450 - val_accuracy: 0.2500
# Epoch 12/100
# 17/17 [==============================] - 5s 286ms/step - loss: 1.7355 - accuracy: 0.2972 - val_loss: 1.7357 - val_accuracy: 0.3167
# Epoch 13/100
# 17/17 [==============================] - 5s 275ms/step - loss: 1.7284 - accuracy: 0.3009 - val_loss: 1.7256 - val_accuracy: 0.3167
# Epoch 14/100
# 17/17 [==============================] - 5s 298ms/step - loss: 1.7098 - accuracy: 0.3556 - val_loss: 1.7059 - val_accuracy: 0.3417
# Epoch 15/100
# 17/17 [==============================] - 6s 336ms/step - loss: 1.6841 - accuracy: 0.3787 - val_loss: 1.6799 - val_accuracy: 0.3333
# Epoch 16/100
# 17/17 [==============================] - 5s 310ms/step - loss: 1.6514 - accuracy: 0.3676 - val_loss: 1.6545 - val_accuracy: 0.4167
# Epoch 17/100
# 17/17 [==============================] - 5s 311ms/step - loss: 1.6166 - accuracy: 0.4231 - val_loss: 1.6155 - val_accuracy: 0.3917
# Epoch 18/100
# 17/17 [==============================] - 5s 302ms/step - loss: 1.5711 - accuracy: 0.4685 - val_loss: 1.5684 - val_accuracy: 0.4417
# Epoch 19/100
# 17/17 [==============================] - 5s 301ms/step - loss: 1.5150 - accuracy: 0.4963 - val_loss: 1.5329 - val_accuracy: 0.4333
# Epoch 20/100
# 17/17 [==============================] - 5s 307ms/step - loss: 1.4694 - accuracy: 0.4954 - val_loss: 1.4717 - val_accuracy: 0.4500
# Epoch 21/100
# 17/17 [==============================] - 5s 307ms/step - loss: 1.4004 - accuracy: 0.5454 - val_loss: 1.4252 - val_accuracy: 0.4333
# Epoch 22/100
# 17/17 [==============================] - 6s 352ms/step - loss: 1.3454 - accuracy: 0.5370 - val_loss: 1.3735 - val_accuracy: 0.4667
# Epoch 23/100
# 17/17 [==============================] - 6s 326ms/step - loss: 1.3069 - accuracy: 0.5389 - val_loss: 1.3198 - val_accuracy: 0.4500
# Epoch 24/100
# 17/17 [==============================] - 6s 325ms/step - loss: 1.2371 - accuracy: 0.5926 - val_loss: 1.2702 - val_accuracy: 0.4917
# Epoch 25/100
# 17/17 [==============================] - 5s 320ms/step - loss: 1.1741 - accuracy: 0.6361 - val_loss: 1.2222 - val_accuracy: 0.5083
# Epoch 26/100
# 17/17 [==============================] - 5s 302ms/step - loss: 1.1317 - accuracy: 0.6324 - val_loss: 1.1828 - val_accuracy: 0.5417
# Epoch 27/100
# 17/17 [==============================] - 7s 432ms/step - loss: 1.0886 - accuracy: 0.6463 - val_loss: 1.1514 - val_accuracy: 0.5083
# Epoch 28/100
# 17/17 [==============================] - 6s 364ms/step - loss: 1.0496 - accuracy: 0.6657 - val_loss: 1.1566 - val_accuracy: 0.5917
# Epoch 29/100
# 17/17 [==============================] - 5s 282ms/step - loss: 1.0259 - accuracy: 0.6546 - val_loss: 1.0873 - val_accuracy: 0.5667
# Epoch 30/100
# 17/17 [==============================] - 5s 270ms/step - loss: 0.9908 - accuracy: 0.6593 - val_loss: 1.0658 - val_accuracy: 0.5667
# Epoch 31/100
# 17/17 [==============================] - 5s 287ms/step - loss: 0.9501 - accuracy: 0.6944 - val_loss: 1.0507 - val_accuracy: 0.5083
# Epoch 32/100
# 17/17 [==============================] - 5s 321ms/step - loss: 0.9355 - accuracy: 0.6870 - val_loss: 1.0329 - val_accuracy: 0.5750
# Epoch 33/100
# 17/17 [==============================] - 6s 368ms/step - loss: 0.8940 - accuracy: 0.7111 - val_loss: 0.9850 - val_accuracy: 0.5917
# Epoch 34/100
# 17/17 [==============================] - 5s 289ms/step - loss: 0.8696 - accuracy: 0.7231 - val_loss: 0.9630 - val_accuracy: 0.6250
# Epoch 35/100
# 17/17 [==============================] - 5s 270ms/step - loss: 0.8482 - accuracy: 0.7278 - val_loss: 0.9467 - val_accuracy: 0.6083
# Epoch 36/100
# 17/17 [==============================] - 5s 267ms/step - loss: 0.8279 - accuracy: 0.7361 - val_loss: 0.9462 - val_accuracy: 0.6750
# Epoch 37/100
# 17/17 [==============================] - 5s 267ms/step - loss: 0.8284 - accuracy: 0.7167 - val_loss: 0.9869 - val_accuracy: 0.5000
# Epoch 38/100
# 17/17 [==============================] - 5s 266ms/step - loss: 0.8124 - accuracy: 0.7343 - val_loss: 0.9021 - val_accuracy: 0.6583
# Epoch 39/100
# 17/17 [==============================] - 5s 268ms/step - loss: 0.7733 - accuracy: 0.7537 - val_loss: 0.8767 - val_accuracy: 0.6083
# Epoch 40/100
# 17/17 [==============================] - 4s 265ms/step - loss: 0
100
# 17/17 [==============================] - 4s 265ms/step - loss: 0.4092 - accuracy: 0.8722 - val_loss: 0.6146 - val_accuracy: 0.7750
# Epoch 85/100
# 17/17 [==============================] - 4s 265ms/step - loss: 0.4220 - accuracy: 0.8676 - val_loss: 0.5748 - val_accuracy: 0.8083
# Epoch 86/100
# 17/17 [==============================] - 5s 293ms/step - loss: 0.4133 - accuracy: 0.8694 - val_loss: 0.5841 - val_accuracy: 0.7833
# Epoch 87/100
# 17/17 [==============================] - 6s 350ms/step - loss: 0.3975 - accuracy: 0.8870 - val_loss: 0.5714 - val_accuracy: 0.8167
# Epoch 88/100
# 17/17 [==============================] - 5s 320ms/step - loss: 0.4015 - accuracy: 0.8806 - val_loss: 0.5643 - val_accuracy: 0.8083
# Epoch 89/100
# 17/17 [==============================] - 5s 290ms/step - loss: 0.3961 - accuracy: 0.8787 - val_loss: 0.5598 - val_accuracy: 0.8000
# Epoch 90/100
# 17/17 [==============================] - 5s 268ms/step - loss: 0.3939 - accuracy: 0.8796 - val_loss: 0.5889 - val_accuracy: 0.7667
# Epoch 91/100
# 17/17 [==============================] - 5s 267ms/step - loss: 0.4017 - accuracy: 0.8787 - val_loss: 0.6141 - val_accuracy: 0.7750
# Epoch 92/100
# 17/17 [==============================] - 5s 267ms/step - loss: 0.3942 - accuracy: 0.8667 - val_loss: 0.5603 - val_accuracy: 0.7833
# Epoch 93/100
# 17/17 [==============================] - 5s 265ms/step - loss: 0.3932 - accuracy: 0.8833 - val_loss: 0.5719 - val_accuracy: 0.8000
# Epoch 94/100
# 17/17 [==============================] - 5s 266ms/step - loss: 0.3813 - accuracy: 0.8861 - val_loss: 0.5520 - val_accuracy: 0.8167
# Epoch 95/100
# 17/17 [==============================] - 4s 266ms/step - loss: 0.3694 - accuracy: 0.8852 - val_loss: 0.5467 - val_accuracy: 0.8000
# Epoch 96/100
# 17/17 [==============================] - 4s 263ms/step - loss: 0.3701 - accuracy: 0.8917 - val_loss: 0.5995 - val_accuracy: 0.7500
# Epoch 97/100
# 17/17 [==============================] - 4s 265ms/step - loss: 0.3713 - accuracy: 0.8833 - val_loss: 0.5558 - val_accuracy: 0.7750
# Epoch 98/100
# 17/17 [==============================] - 4s 264ms/step - loss: 0.3653 - accuracy: 0.8870 - val_loss: 0.5556 - val_accuracy: 0.7667
# Epoch 99/100
# 17/17 [==============================] - 5s 266ms/step - loss: 0.3702 - accuracy: 0.8870 - val_loss: 0.5699 - val_accuracy: 0.7833
# Epoch 100/100
# 17/17 [==============================] - 4s 265ms/step - loss: 0.3580 - accuracy: 0.8880 - val_loss: 0.5483 - val_accuracy: 0.8000

# %%
# saving the model:
conv_model.save("./saved_model_2/FingerSigns.h5")

# %%
# The history.history["loss"] entry is a dictionary with as many values as epochs that the
# model was trained on. 
df_loss_acc = pd.DataFrame(conv_model.history.history)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'})
df_acc= df_loss_acc[['accuracy','val_accuracy']]
df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'})
df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
df_acc.plot(title='Model Accuracy',figsize=(12,8)).set(xlabel='Epoch',ylabel='Accuracy')
# Out:
# [Text(0.5, 0, 'Epoch'), Text(0, 0.5, 'Accuracy')]

# %%
# Testing our model:

# Test 1:
image_index = 10
Test_image_1 = X_test[image_index]

plt.imshow(Test_image_1)
plt.show()

# prediction of conv_model():
prediction = np.argmax(conv_model.predict(Test_image_1.reshape(1,64,64,3)), axis=1)
print(f"The number is {prediction}")
# Out:
# The number is [5]

# %%
# Test 2:
image_index = 0
Test_image_2 = X_test[image_index]

plt.imshow(Test_image_2)
plt.show()

# prediction of conv_model():
prediction = np.argmax(conv_model.predict(Test_image_2.reshape(1,64,64,3)), axis=1)
print(f"The number is {prediction}")
# Out:
# The number is [0]

# %% [markdown]
# ## The End
